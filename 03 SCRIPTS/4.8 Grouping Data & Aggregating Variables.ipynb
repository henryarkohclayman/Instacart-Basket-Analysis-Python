# %% [markdown]
# IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# IMPORTING DATA

# %%
# Creating Path
path = r'C:\Users\henry\OneDrive\042025Instacart Basket Analysis'

# %%
# Importing pkl file
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 DATA', 'Prepared Data', '.pkl'))

# %%
# Creating a subset of 1 million rows
df = ords_prods_merge[:1000000]

# %%
# Check shape of new subset
df.shape
# Out:
# (1000000, 17)

# %%
df.head(10)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
# 5           1  Chocolate Sandwich Cookies        61             19     5.8
# 6           1  Chocolate Sandwich Cookies        61             19     5.8
# 7           1  Chocolate Sandwich Cookies        61             19     5.8
# 8           1  Chocolate Sandwich Cookies        61             19     5.8
# 9           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   3139998      138            28          6                 11
# ...

# %%
# Using the 'groupby()' function 
df.groupby('product_name')

# %%
# Aggregating Data with agg()
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %% [markdown]
# When comparing the subset of 100,000 rows with the entire dataframe, a significant difference emerges in the coverage of departments. The full dataframe contains all 21 department_id. This broader coverage in the full dataset results in more comprehensive and representative trends. Additionally, the mean order_number for each department varies between the two datasets, reflecting different customer behaviors and purchase patterns.The subset may misrepresent certain customer ordering patterns. This highlights the importance of using the entire dataset for more accurate analysis.

# %%
# Aggregations without the use of the agg() function
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_number, dtype: float64

# %%
# Performing multiple aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.577493   1  99
# 2                17.320781   1  96
# 3                16.084944   1  99
# 4                17.530458   1  99
# 5                14.763075   1  99
# 6                16.658449   1  99
# 7                17.031590   1  99
# 8                15.076662   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.447411   1  99
# 12               14.327957   1  99
# 13               16.548642   1  99
# 14               16.960241   1  99
# 15               16.121948   1  99
# 16               17.803851   1  99
# 17               15.593633   1  99
# 18               19.674252   1  99
# 19               16.899756   1  99
# 20               16.255442   1  99
# 21               25.535479   1  98

# %% [markdown]
# Aggregating Data with transform function

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\henry\AppData\Local\Temp\ipykernel_23956\1681540670.py:1: FutureWarning: The provided callable <function max at 0x0000023977AF8400> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# ...

# %%
# first 100 rows
ords_prods_merge.head(100)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# ..         ...                         ...       ...            ...     ...
# 95           1  Chocolate Sandwich Cookies        61             19     5.8
# 96           1  Chocolate Sandwich Cookies        61             19     5.8
# 97           1  Chocolate Sandwich Cookies        61             19     5.8
# 98           1  Chocolate Sandwich Cookies        61             19     5.8
# 99           1  Chocolate Sandwich Cookies        61             19     5.8
#
# ...

# %% [markdown]
# Creating loyalty labels or flags

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check output
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15874128
# Loyal customer      10282763
# New customer         6242841
# Name: count, dtype: int64

# %%
# Check Loyalty flag in dataframe
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number','max_order']].head(15)
# Out:
#     user_id      loyalty_flag  order_number  max_order
# 0       138  Regular customer            28         32
# 1       138  Regular customer            30         32
# 2       709      New customer             2          5
# 3       764      New customer             1          3
# 4       764      New customer             3          3
# 5       777  Regular customer            16         26
# 6       825      New customer             3          9
# 7       910  Regular customer            12         12
# 8      1052  Regular customer            10         20
# 9      1052  Regular customer            15         20
# 10     1379      New customer             1         10
# 11     1480    Loyal customer            36         43
# 12     1480    Loyal customer            38         43
# 13     1480    Loyal customer            39         43
# 14     1494  Regular customer             6         13

# %%
# Basic statistics of each loyalty flag
ords_prods_merge.groupby(['loyalty_flag']).agg({'prices':['mean','min','max']})
# Out:
#                     prices
#                       mean  min   max
# loyalty_flag
# Loyal customer    7.773575  1.0  25.0
# New customer      7.801206  1.0  25.0
# Regular customer  7.798262  1.0  25.0

# %% [markdown]
# The average prices are nearly identical across loyalty groups: Loyal customers spend $7.77, new customers $7.80, and regular customers $7.80. Minimum and maximum prices are consistent at $1.00 and $25.00. This suggests loyalty status does not significantly influence product-level spending.

# %% [markdown]
# Column for average spender

# %%
# Creating column for average spender
ords_prods_merge['average_spend']=ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\henry\AppData\Local\Temp\ipykernel_23956\655122787.py:2: FutureWarning: The provided callable <function mean at 0x0000023977AF8E00> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['average_spend']=ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Creating flag for low and high spender
ords_prods_merge.loc[ords_prods_merge['average_spend']<10,'spender_flag']='Low_spender'

ords_prods_merge.loc[ords_prods_merge['average_spend']>= 10, 'spender_flag'] = 'High_spender'

# %%
# Check output
ords_prods_merge['spender_flag'].value_counts(dropna = False)
# Out:
# spender_flag
# Low_spender     32280013
# High_spender      119719
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'average_spend', 'spender_flag', 'prices']].head(50)
# Out:
#     user_id  average_spend spender_flag  prices
# 0       138       6.935811  Low_spender     5.8
# 1       138       6.935811  Low_spender     5.8
# 2       709       7.930208  Low_spender     5.8
# 3       764       4.972414  Low_spender     5.8
# 4       764       4.972414  Low_spender     5.8
# 5       777       6.935398  Low_spender     5.8
# 6       825       5.957576  Low_spender     5.8
# 7       910       6.680000  Low_spender     5.8
# 8      1052       7.162500  Low_spender     5.8
# 9      1052       7.162500  Low_spender     5.8
# 10     1379       5.813636  Low_spender     5.8
# 11     1480       5.081633  Low_spender     5.8
# 12     1480       5.081633  Low_spender     5.8
# 13     1480       5.081633  Low_spender     5.8
# 14     1494       6.803797  Low_spender     5.8
# 15     1494       6.803797  Low_spender     5.8
# 16     1494       6.803797  Low_spender     5.8
# 17     1540       6.607122  Low_spender     5.8
# 18     1540       6.607122  Low_spender     5.8
# ...

# %% [markdown]
# Columns for frequent users

# %%
# Creating a column for frequent users
ords_prods_merge['Customer_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\henry\AppData\Local\Temp\ipykernel_23956\928642412.py:2: FutureWarning: The provided callable <function median at 0x0000023977D0FA60> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['Customer_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Creating frequency flags
ords_prods_merge.loc[ords_prods_merge['Customer_frequency'] > 20, 'frequency_flag'] = 'Non_frequent_customer'

ords_prods_merge.loc[(ords_prods_merge['Customer_frequency']>10) & (ords_prods_merge['Customer_frequency']<=20),'frequency_flag'] = 'Regular customer'

ords_prods_merge.loc[ords_prods_merge['Customer_frequency'] <= 10, 'frequency_flag'] = 'Frequent Customer'

# %%
# check output
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# frequency_flag
# Frequent Customer        21556644
# Regular customer          7207340
# Non_frequent_customer     3635743
# NaN                             5
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id','days_since_prior_order', 'Customer_frequency', 'frequency_flag']].head(50)
# Out:
#     user_id  days_since_prior_order  Customer_frequency         frequency_flag
# 0       138                     3.0                 8.0      Frequent Customer
# 1       138                    20.0                 8.0      Frequent Customer
# 2       709                     6.0                 8.0      Frequent Customer
# 3       764                     NaN                 9.0      Frequent Customer
# 4       764                     9.0                 9.0      Frequent Customer
# 5       777                    26.0                11.0       Regular customer
# 6       825                    30.0                20.0       Regular customer
# 7       910                    30.0                 6.0      Frequent Customer
# 8      1052                    19.0                10.0      Frequent Customer
# 9      1052                    15.0                10.0      Frequent Customer
# 10     1379                     NaN                20.0       Regular customer
# ...

# %% [markdown]
# EXPORT DATA

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 DATA', 'Prepared Data', 'Aggregated_ords_prods_merge.pkl'))
